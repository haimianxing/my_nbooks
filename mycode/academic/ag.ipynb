# %%
import pandas as pd
df = pd.read_csv('./df_train2.csv')
df_t = pd.read_csv('./df_test2.csv')

# %%
def feature_engineering(df,df_test,target,n_jobs=4):
    from openfe import OpenFE, transform
    train_x,test_x,train_y,n_jobs = df.drop(target,axis=1),df_test,df[target],n_jobs
    ofe = OpenFE()
    features = ofe.fit(data=train_x, label=train_y, n_jobs=n_jobs)  # generate new features
    train_x, test_x = transform(train_x, test_x, features, n_jobs=n_jobs) # transform the train and test data according to generated features.
    return train_x, test_x

def ag_tuning(df_train,df_test,id_name='0620',label='Survived',loss='log_loss',presets='best_quality',dynamic_stacking=True,folds=10,time=60*3):
    from autogluon.tabular import TabularPredictor
    from autogluon.features.generators import AutoMLPipelineFeatureGenerator
    auto_ml_pipeline_feature_generator = AutoMLPipelineFeatureGenerator()
    from autogluon.tabular.configs.hyperparameter_configs import get_hyperparameter_config
    
    custom_hyperparameters = get_hyperparameter_config('default')
    
    def get_oof_ts(predictor,_train_x,_test_x,ids,label):
        predictions_oof = predictor.predict_oof()
        prdict_y = predictor.predict(_test_x)
        pd.DataFrame({'oofs': predictions_oof, 'predict_y': prdict_y}).to_csv(f'model_hc_systhis_{ids}.csv',index=False)
        _train_x[ids],_test_x[ids]  = predictions_oof,prdict_y
        _train_x.to_csv(f'model_hc_tr_{ids}.csv',index=False)
        _test_x.to_csv(f'model_hc_ts_{ids}.csv',index=False)
        return predictions_oof,prdict_y
    
    predictor = TabularPredictor(
        label=label,
        # problem_type=problem,#'binary',
        eval_metric=loss #'acc'
    ).fit(
        df_train, #df, #df_train,
        presets='best_quality',
    #     unlabeled_data = df_test2,   #df_test2.drop(columns='Survived'), #df_train[800:].drop(columns='Survived'),
        # auto_stack=True,
        feature_generator=auto_ml_pipeline_feature_generator,
        ag_args_ensemble = {
            'fold_fitting_strategy':'sequential_local',
            "stopping_metric": "log_loss",
        },
        dynamic_stacking=dynamic_stacking,
    #     num_stack_levels=1,
        num_bag_folds=folds,
        # time_limit=time,
        # included_model_types = ['XGB','NN_TORCH','CATBOOST','LIGHTGBM','FAST_AI'],
    #     excluded_model_types = ['NN_TORCH'],
        # use_bag_holdout=True,
        # hyperparameters=custom_hyperparameters,
        hyperparameter_tune_kwargs='auto',#hyperparameter_tune_kwargs,
        # keep_only_best = True,
    )
    oofs,predictions = get_oof_ts(predictor,df_train,df_test,id_name,label)
    return predictions,oofs,predictor
# show_info(predictor,train_x)

def show_info(predictor,df_train):
    print('++++++++++++++++++++++++++++++++++++++++++++++')
    print(predictor.fit_summary())
    print('++++++++++++++++++++++++++++++++++++++++++++++')
    print(predictor.leaderboard(df_train,silent=True))
    print('++++++++++++++++++++++++++++++++++++++++++++++')
    print(predictor.feature_importance(df_train,silent=True))
    print('++++++++++++++++++++++++++++++++++++++++++++++')

from sklearn.metrics import mean_squared_error,roc_auc_score
def hill_climbers(files,train_path,test_path,label='Survived',func=roc_auc_score):
    from hillclimbers import climb_hill, partial
    
    train,test = pd.read_csv(train_path),pd.read_csv(test_path)
    oofs,pred = pd.DataFrame(),pd.DataFrame()
    for i in range(len(files)):
        tmp = pd.read_csv(files[i])
        oofs[f'm{i}'],pred[f'm{i}'] = tmp['oofs'].dropna(),tmp['predict_y'].dropna()

    test_preds, oof_preds = climb_hill(
        train=train, 
        oof_pred_df=oofs, 
        test_pred_df=pred,
        target=label,
        objective="maximize",
        eval_metric=partial(func),
        negative_weights=True, 
        precision=0.001,
        plot_hill=True, 
        plot_hist=True,
        return_oof_preds=True
    )
    return test_preds, oof_preds
# a,b = hill_climbers(files,train_path,test_path=test_path,label='Survived')

def titanic_acc(predictions):
    from sklearn.metrics import accuracy_score
    acc= pd.read_csv('./acc.csv')
    acc_ans = acc.Survived
    print(accuracy_score(acc_ans,predictions)) 

def submission(predictions,test_x,cols,label,id_name):
    test_x[label] = predictions
    test_x[cols].to_csv(f'submission_{id_name}.csv',index=False)
    
    
def pipline(df1,df1_test,label='Survived',time=60*3,id_name='0620_v3',loss='log_loss',cols=['1','2']):
    # train_x, test_x = feature_engineering(df1,df1_test,label)
    # train_x[label] = df1[label]
    # train_x.to_csv('tr.csv',index=False)
    # test_x.to_csv('ts.csv',index=False)
    train_x,test_x = df1,df1_test
    predictions,oofs,predictor = ag_tuning(train_x,test_x,id_name=id_name,time=time,loss=loss,label=label)
    show_info(predictor,train_x)
    # titanic_acc(predictions)
    submission(predictions,test_x,cols,label,id_name)
    return predictions

# %%
import numpy as np
def transform(df):
    features = df.columns.tolist()
    sorted_new =  np.sort(df.values, axis=1)
    df['mean_features'] = 0.1 * df[features].mean(axis=1)
    df['std_features'] = df[features].std(axis=1)
    df['max_features'] = df[features].max(axis=1)
    df['min_features'] = df[features].min(axis=1)
    df['median_features'] = 0.1 * df[features].median(axis=1)
    df['sum_features'] = 0.1 * df[features].sum(axis=1)
    df1 = pd.concat([df, pd.DataFrame(sorted_new, index=df.index)], axis=1)
    df1 = df1.drop(features, axis=1)
    df1.columns = df1.columns.astype('str')
    return df

df_train = transform(df.drop(['Target'],axis=1))
df_test = transform(df_t.drop([],axis=1))
df_train
# Out:
#        Marital status  Application mode  Application order  Course  \
# 0                   1                 1                  1    9238
# 1                   1                17                  1    9238
# 2                   1                17                  2    9254
# 3                   1                 1                  3    9500
# 4                   1                 1                  2    9500
# ...               ...               ...                ...     ...
# 76513               1                17                  1    9254
# 76514               1                 1                  6    9254
# 76515               5                17                  1    9085
# 76516               1                 1                  3    9070
# 76517               1                 1                  1    9773
#
#        Daytime/evening attendance  Previous qualification  \
# 0                               1                       1
# 1                               1                       1
# 2                               1                       1
# 3                               1                       1
# 4                               1                       1
# ...                           ...                     ...
# 76513                           1                       1
# 76514                           1                       1
# 76515                           1                       1
# 76516                           1                       1
# 76517                           1                       1
#
#        Previous qualification (grade)  Nacionality  Mother's qualification  \
# 0                               126.0            1                       1
# 1                               125.0            1                      19
# 2                               137.0            1                       3
# 3                               131.0            1                      19
# 4                               132.0            1                      19
# ...                               ...          ...                     ...
# 76513                           121.0            1                      19
# 76514                           125.0            1                       1
# 76515                           138.0            1                      37
# 76516                           136.0            1                      38
# 76517                           133.1            1                      19
#
#        Father's qualification  ...  \
# 0                          19  ...
# 1                          19  ...
# 2                          19  ...
# 3                           3  ...
# 4                          37  ...
# ...                       ...  ...
# 76513                       1  ...
# 76514                      38  ...
# 76515                      37  ...
# 76516                      37  ...
# 76517                      19  ...
#
#        Curricular units 2nd sem (without evaluations)  Unemployment rate  \
# 0                                                   0               11.1
# 1                                                   0               11.1
# 2                                                   0               16.2
# 3                                                   0               11.1
# 4                                                   0                7.6
# ...                                               ...                ...
# 76513                                               0               13.9
# 76514                                               0                9.4
# 76515                                               1                9.4
# 76516                                               0                7.6
# 76517                                               0               15.5
#
#        Inflation rate   GDP  mean_features  std_features  max_features  \
# 0                 0.6  2.02      26.722913   1538.108351        9238.0
# 1                 0.6  2.02      26.775333   1538.010902        9238.0
# 2                 0.3 -0.92      26.759111   1540.869739        9254.0
# 3                 0.6  2.02      27.503420   1581.694142        9500.0
# 4                 2.6  0.32      27.595796   1581.530601        9500.0
# ...               ...   ...            ...           ...           ...
# 76513            -0.3  0.79      26.783769   1540.722942        9254.0
# 76514            -0.8 -3.12      26.888764   1540.591116        9254.0
# 76515            -0.8 -3.12      26.551889   1512.214797        9085.0
# 76516             2.6  0.32      26.306444   1510.071542        9070.0
# 76517             2.8 -4.06      28.310667   1627.118819        9773.0
#
#        min_features  median_features  sum_features
# 0              0.00            0.100    962.024857
# 1              0.00            0.100    963.912000
# 2             -0.92            0.100    963.328000
# 3              0.00            0.201    990.123125
# 4              0.00            0.230    993.448667
# ...             ...              ...           ...
# 76513         -0.30            0.100    964.215667
# 76514         -3.12            0.100    967.995500
# 76515         -3.12            0.450    955.868000
# 76516          0.00            0.100    947.032000
# 76517         -4.06            0.190   1019.184000
#
# [76518 rows x 42 columns]

# %%
df_cp = df_train.combine_first(df)
df_cp
# Out:
#        Admission grade  Age at enrollment  Application mode  \
# 0                122.6                 18                 1
# 1                119.8                 18                17
# 2                144.7                 18                17
# 3                126.1                 18                 1
# 4                120.1                 18                 1
# ...                ...                ...               ...
# 76513            116.5                 18                17
# 76514            131.6                 19                 1
# 76515            123.3                 19                17
# 76516            124.8                 18                 1
# 76517            131.0                 19                 1
#
#        Application order  Course  Curricular units 1st sem (approved)  \
# 0                      1    9238                                    6
# 1                      1    9238                                    4
# 2                      2    9254                                    0
# 3                      3    9500                                    7
# 4                      2    9500                                    6
# ...                  ...     ...                                  ...
# 76513                  1    9254                                    6
# 76514                  6    9254                                    4
# 76515                  1    9085                                    4
# 76516                  3    9070                                    0
# 76517                  1    9773                                    6
#
#        Curricular units 1st sem (credited)  \
# 0                                        0
# 1                                        0
# 2                                        0
# 3                                        0
# 4                                        0
# ...                                    ...
# 76513                                    0
# 76514                                    0
# 76515                                    0
# 76516                                    0
# 76517                                    0
#
#        Curricular units 1st sem (enrolled)  \
# 0                                        6
# 1                                        6
# 2                                        6
# 3                                        7
# 4                                        7
# ...                                    ...
# 76513                                    6
# 76514                                    6
# 76515                                    5
# 76516                                    6
# 76517                                    6
#
#        Curricular units 1st sem (evaluations)  \
# 0                                           6
# 1                                           8
# 2                                           0
# 3                                           9
# 4                                          12
# ...                                       ...
# 76513                                       9
# 76514                                      22
# 76515                                      13
# 76516                                       0
# 76517                                       6
#
#        Curricular units 1st sem (grade)  ...  Scholarship holder    Target  \
# 0                             14.500000  ...                   1  Graduate
# 1                             11.600000  ...                   0   Dropout
# 2                              0.000000  ...                   0   Dropout
# 3                             12.591250  ...                   1  Enrolled
# 4                             12.933333  ...                   0  Graduate
# ...                                 ...  ...                 ...       ...
# 76513                         10.666667  ...                   1  Graduate
# 76514                         13.000000  ...                   0  Graduate
# 76515                         12.500000  ...                   0  Enrolled
# 76516                          0.000000  ...                   0   Dropout
# 76517                         12.833333  ...                   0  Graduate
#
#        Tuition fees up to date  Unemployment rate  max_features  \
# 0                            1               11.1        9238.0
# 1                            1               11.1        9238.0
# 2                            1               16.2        9254.0
# 3                            1               11.1        9500.0
# 4                            1                7.6        9500.0
# ...                        ...                ...           ...
# 76513                        1               13.9        9254.0
# 76514                        1                9.4        9254.0
# 76515                        1                9.4        9085.0
# 76516                        1                7.6        9070.0
# 76517                        1               15.5        9773.0
#
#        mean_features  median_features  min_features  std_features  \
# 0          26.722913            0.100          0.00   1538.108351
# 1          26.775333            0.100          0.00   1538.010902
# 2          26.759111            0.100         -0.92   1540.869739
# 3          27.503420            0.201          0.00   1581.694142
# 4          27.595796            0.230          0.00   1581.530601
# ...              ...              ...           ...           ...
# 76513      26.783769            0.100         -0.30   1540.722942
# 76514      26.888764            0.100         -3.12   1540.591116
# 76515      26.551889            0.450         -3.12   1512.214797
# 76516      26.306444            0.100          0.00   1510.071542
# 76517      28.310667            0.190         -4.06   1627.118819
#
#        sum_features
# 0        962.024857
# 1        963.912000
# 2        963.328000
# 3        990.123125
# 4        993.448667
# ...             ...
# 76513    964.215667
# 76514    967.995500
# 76515    955.868000
# 76516    947.032000
# 76517   1019.184000
#
# [76518 rows x 43 columns]

# %%
df_test_cp  = df_test.combine_first(df_t)
df_test_cp
# Out:
#        Admission grade  Age at enrollment  Application mode  \
# 0                152.1                 18                 1
# 1                116.5                 19                 1
# 2                114.2                 18                 1
# 3                130.0                 23                44
# 4                106.0                 26                39
# ...                ...                ...               ...
# 51007            124.7                 19                 1
# 51008            140.0                 33                39
# 51009            120.4                 20                 1
# 51010            126.3                 18                 1
# 51011            122.0                 18                 1
#
#        Application order  Course  Curricular units 1st sem (approved)  \
# 0                      1    9500                                    0
# 1                      1    9238                                    6
# 2                      1    9238                                    6
# 3                      1    9147                                    5
# 4                      1    9670                                    3
# ...                  ...     ...                                  ...
# 51007                  2     171                                    0
# 51008                  1    9119                                    0
# 51009                  1     171                                    0
# 51010                  3    9773                                    5
# 51011                  1     171                                    0
#
#        Curricular units 1st sem (credited)  \
# 0                                        0
# 1                                        0
# 2                                        0
# 3                                        2
# 4                                        0
# ...                                    ...
# 51007                                    0
# 51008                                    0
# 51009                                    0
# 51010                                    0
# 51011                                    0
#
#        Curricular units 1st sem (enrolled)  \
# 0                                        7
# 1                                        6
# 2                                        6
# 3                                        6
# 4                                        6
# ...                                    ...
# 51007                                    0
# 51008                                    5
# 51009                                    0
# 51010                                    6
# 51011                                    0
#
#        Curricular units 1st sem (evaluations)  \
# 0                                           0
# 1                                           7
# 2                                          11
# 3                                          15
# 4                                           9
# ...                                       ...
# 51007                                       0
# 51008                                       6
# 51009                                       0
# 51010                                       8
# 51011                                       0
#
#        Curricular units 1st sem (grade)  ...  Previous qualification (grade)  \
# 0                              0.000000  ...                           141.0
# 1                             14.857143  ...                           128.0
# 2                             12.000000  ...                           118.0
# 3                             11.500000  ...                           130.0
# 4                             11.000000  ...                           110.0
# ...                                 ...  ...                             ...
# 51007                          0.000000  ...                           128.0
# 51008                          0.000000  ...                           133.1
# 51009                          0.000000  ...                           127.0
# 51010                         12.600000  ...                           132.0
# 51011                          0.000000  ...                           129.0
#
#        Scholarship holder  Tuition fees up to date  Unemployment rate  \
# 0                       0                        0               13.9
# 1                       0                        1               11.1
# 2                       1                        1               15.5
# 3                       1                        1                8.9
# 4                       0                        1                7.6
# ...                   ...                      ...                ...
# 51007                   0                        1               15.5
# 51008                   0                        0                9.4
# 51009                   0                        0               15.5
# 51010                   0                        0                7.6
# 51011                   0                        0                7.6
#
#        max_features  mean_features  median_features  min_features  \
# 0            9500.0      27.376361           0.0395         -0.30
# 1            9238.0      26.712714           0.1000          0.00
# 2            9238.0      26.698444           0.1000         -4.06
# 3            9147.0      26.775861           0.3000          0.00
# 4            9670.0      27.992185           0.2300          0.00
# ...             ...            ...              ...           ...
# 51007         171.0       1.549833           0.0500         -4.06
# 51008        9119.0      26.640500           0.1000         -3.12
# 51009         171.0       1.321222           0.0000         -4.06
# 51010        9773.0      28.278944           0.2800          0.00
# 51011         171.0       1.532000           0.0660          0.00
#
#        std_features  sum_features
# 0       1582.002355    985.549000
# 1       1538.118351    961.657714
# 2       1538.117590    961.144000
# 3       1522.457632    963.931000
# 4       1609.929880   1007.718667
# ...             ...           ...
# 51007     40.045161     55.794000
# 51008   1517.926969    959.058000
# 51009     39.414092     47.564000
# 51010   1627.160057   1018.042000
# 51011     39.888536     55.152000
#
# [51012 rows x 42 columns]

# %%
pipline(df_cp.sample(frac=0.7),df_test_cp,label='Target',loss='log_loss',time=60*60*6,id_name='academic_0624_v1',cols=['id','Target'])
# Out:
# 2024-06-24 02:39:54,882	INFO timeout.py:54 -- Reached timeout of 14.73409137556347 seconds. Stopping all trials.
# 2024-06-24 02:39:54,896	WARNING experiment_state.py:205 -- Experiment state snapshotting has been triggered multiple times in the last 5.0 seconds. A snapshot is forced if `CheckpointConfig(num_to_keep)` is set, and a trial has checkpointed >= `num_to_keep` times since the last snapshot.
# You may want to consider increasing the `CheckpointConfig(num_to_keep)` or decreasing the frequency of saving checkpoints.
# You can suppress this error by setting the environment variable TUNE_WARN_EXCESSIVE_EXPERIMENT_CHECKPOINT_SYNC_THRESHOLD_S to a smaller value than the current threshold (5.0).
# 2024-06-24 02:39:54,900	INFO tune.py:1016 -- Wrote the latest version of all result files and experiment state to 'E:/proj/my_nbooks/mycode/academic/AutogluonModels/ag-20240623_172750/models/NeuralNetTorch_r89_BAG_L1' in 0.0150s.
# 2024-06-24 02:39:54,906	WARNING experiment_analysis.py:190 -- Failed to fetch metrics for 2 trial(s):
# - fa6448c3: FileNotFoundError('Could not fetch metrics for fa6448c3: both result.json and progress.csv were not found at E:/proj/my_nbooks/mycode/academic/AutogluonModels/ag-20240623_172750/models/NeuralNetTorch_r89_BAG_L1/fa6448c3')
# - eb08b5ba: FileNotFoundError('Could not fetch metrics for eb08b5ba: both result.json and progress.csv were not found at E:/proj/my_nbooks/mycode/academic/AutogluonModels/ag-20240623_172750/models/NeuralNetTorch_r89_BAG_L1/eb08b5ba')
# No model was trained during hyperparameter tuning NeuralNetTorch_r89_BAG_L1... Skipping this model.
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.0s of the -723.32s of remaining time.
# 	Ensemble Weights: {'XGBoost_r95_BAG_L1': 0.36, 'CatBoost_r163_BAG_L1': 0.32, 'RandomForestEntr_BAG_L1': 0.12, 'RandomForest_r39_BAG_L1': 0.08, 'RandomForest_r127_BAG_L1': 0.08, 'NeuralNetFastAI_r88_BAG_L1': 0.04}
# 	-0.4469	 = Validation score   (-log_loss)
# 	7.9s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting 108 L2 models ...
# Fitting model: WeightedEnsemble_L3 ... Training model for up to 360.0s of the -735.88s of remaining time.
# 	Ensemble Weights: {'XGBoost_r95_BAG_L1': 0.36, 'CatBoost_r163_BAG_L1': 0.32, 'RandomForestEntr_BAG_L1': 0.12, 'RandomForest_r39_BAG_L1': 0.08, 'RandomForest_r127_BAG_L1': 0.08, 'NeuralNetFastAI_r88_BAG_L1': 0.04}
# 	-0.4469	 = Validation score   (-log_loss)
# 	7.78s	 = Training   runtime
# 	0.01s	 = Validation runtime
# AutoGluon training complete, total runtime = 3446.45s ... Best model: WeightedEnsemble_L2 | Estimated inference throughput: 6624.9 rows/s (10713 batch size)
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels\ag-20240623_172750")
# ++++++++++++++++++++++++++++++++++++++++++++++
# *** Summary of fit() ***
# Estimated performance of each model:
#                           model  score_val eval_metric  pred_time_val   fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0           WeightedEnsemble_L3  -0.446944    log_loss       4.045482  80.381608                0.012000           7.781796            3       True         49
# 1           WeightedEnsemble_L2  -0.446944    log_loss       4.047482  80.499042                0.013999           7.899230            2       True         48
# 2            XGBoost_r95_BAG_L1  -0.449831    log_loss       0.406260  14.153855                0.406260          14.153855            1       True         46
# 3          CatBoost_r163_BAG_L1  -0.450737    log_loss       0.045991  13.938991                0.045991          13.938991            1       True         43
# 4          ExtraTrees_r4_BAG_L1  -0.458633    log_loss       1.390878  10.911598                1.390878          10.911598            1       True         34
# 5       RandomForest_r34_BAG_L1  -0.460673    log_loss       0.947878  10.643556                0.947878          10.643556            1       True         30
# 6          CatBoost_r167_BAG_L1  -0.462862    log_loss       0.045991  14.067638                0.045991          14.067638            1       True         21
# 7          CatBoost_r177_BAG_L1  -0.462909    log_loss       0.052000  13.957280                0.052000          13.957280            1       True          7
# 8           CatBoost_r49_BAG_L1  -0.466249    log_loss       0.055991  13.990483                0.055991          13.990483            1       True         25
# 9          CatBoost_r198_BAG_L1  -0.466944    log_loss       0.044992  15.128544                0.044992          15.128544            1       True         44
# 10       ExtraTrees_r126_BAG_L1  -0.467616    log_loss       3.298999   9.676782                3.298999           9.676782            1       True         41
# 11  NeuralNetFastAI_r187_BAG_L1  -0.471066    log_loss       0.438286  13.755343                0.438286          13.755343            1       True         45
# 12          LightGBM_r94_BAG_L1  -0.482733    log_loss       0.439003  14.607882                0.439003          14.607882            1       True         31
# 13   NeuralNetFastAI_r88_BAG_L1  -0.485912    log_loss       0.557202  14.200957                0.557202          14.200957            1       True         36
# 14        ExtraTrees_r49_BAG_L1  -0.490311    log_loss       3.433643  11.033385                3.433643          11.033385            1       True         26
# 15  NeuralNetFastAI_r143_BAG_L1  -0.495797    log_loss       0.592002  14.014552                0.592002          14.014552            1       True         16
# 16  NeuralNetFastAI_r134_BAG_L1  -0.497961    log_loss       0.635551  13.576956                0.635551          13.576956            1       True         29
# 17  NeuralNetFastAI_r111_BAG_L1  -0.499124    log_loss       0.484010  13.422366                0.484010          13.422366            1       True         33
# 18          CatBoost_r12_BAG_L1  -0.507718    log_loss       0.047009  13.921575                0.047009          13.921575            1       True         40
# 19  NeuralNetFastAI_r156_BAG_L1  -0.518240    log_loss       0.416003  13.907968                0.416003          13.907968            1       True         18
# 20      RandomForestEntr_BAG_L1  -0.519145    log_loss       1.758325   8.603080                1.758325           8.603080            1       True          3
# 21          LightGBM_r15_BAG_L1  -0.519968    log_loss       0.344008  14.454400                0.344008          14.454400            1       True         23
# 22      RandomForestGini_BAG_L1  -0.520388    log_loss       1.892724   9.537316                1.892724           9.537316            1       True          2
# 23     RandomForest_r127_BAG_L1  -0.525006    log_loss       0.570998  10.880188                0.570998          10.880188            1       True         28
# 24            XGBoost_BAG_L1\T2  -0.530223    log_loss       0.227010  11.227513                0.227010          11.227513            1       True          5
# 25          LightGBM_r96_BAG_L1  -0.561950    log_loss       0.483004  14.503854                0.483004          14.503854            1       True         10
# 26          CatBoost_r70_BAG_L1  -0.568455    log_loss       0.062000  13.933136                0.062000          13.933136            1       True         17
# 27         LightGBM_r131_BAG_L1  -0.586027    log_loss       0.340485  14.591870                0.340485          14.591870            1       True          8
# 28           CatBoost_r6_BAG_L1  -0.589162    log_loss       0.629084  14.071275                0.629084          14.071275            1       True         38
# 29      RandomForest_r39_BAG_L1  -0.590270    log_loss       0.694706  10.822741                0.694706          10.822741            1       True         20
# 30           CatBoost_BAG_L1\T1  -0.591128    log_loss       0.080002  12.805397                0.080002          12.805397            1       True          4
# 31           XGBoost_r34_BAG_L1  -0.616383    log_loss       0.419000  14.252050                0.419000          14.252050            1       True         47
# 32           CatBoost_r5_BAG_L1  -0.631557    log_loss       0.647580  14.572292                0.647580          14.572292            1       True         37
# 33          CatBoost_r50_BAG_L1  -0.634496    log_loss       0.498986  14.270607                0.498986          14.270607            1       True         13
# 34         CatBoost_r128_BAG_L1  -0.646067    log_loss       0.049997  13.849498                0.049997          13.849498            1       True         32
# 35          CatBoost_r86_BAG_L1  -0.648919    log_loss       0.049000  13.822857                0.049000          13.822857            1       True         24
# 36           CatBoost_r9_BAG_L1  -0.653758    log_loss       0.061988  13.943293                0.061988          13.943293            1       True          9
# 37          CatBoost_r69_BAG_L1  -0.673767    log_loss       0.675998  14.261036                0.675998          14.261036            1       True         14
# 38  NeuralNetFastAI_r100_BAG_L1  -0.679108    log_loss       0.547997  12.847395                0.547997          12.847395            1       True         42
# 39         LightGBMLarge_BAG_L1  -0.710999    log_loss       0.132987  13.356308                0.132987          13.356308            1       True          6
# 40         CatBoost_r137_BAG_L1  -0.716945    log_loss       0.791060  14.777922                0.791060          14.777922            1       True         11
# 41         LightGBM_r143_BAG_L1  -0.752009    log_loss       0.179627  14.563717                0.179627          14.563717            1       True         27
# 42   NeuralNetFastAI_r65_BAG_L1  -0.775071    log_loss       0.498995  13.933954                0.498995          13.933954            1       True         35
# 43         CatBoost_r180_BAG_L1  -0.784844    log_loss       0.453005  13.497142                0.453005          13.497142            1       True         39
# 44         LightGBM_r161_BAG_L1  -0.806071    log_loss       0.220997  14.801035                0.220997          14.801035            1       True         15
# 45           XGBoost_r98_BAG_L1  -0.861961    log_loss       0.182000  14.268306                0.182000          14.268306            1       True         22
# 46         LightGBM_r196_BAG_L1  -0.925746    log_loss       0.209002  14.366760                0.209002          14.366760            1       True         19
# 47          CatBoost_r13_BAG_L1  -1.004471    log_loss       0.499630  13.845011                0.499630          13.845011            1       True         12
# 48        KNeighborsDist_BAG_L1  -1.690782    log_loss       6.627963   6.834961                6.627963           6.834961            1       True          1
# Number of models trained: 49
# Types of models trained:
# {'StackerEnsembleModel_XT', 'StackerEnsembleModel_LGB', 'WeightedEnsembleModel', 'StackerEnsembleModel_NNFastAiTabular', 'StackerEnsembleModel_RF', 'StackerEnsembleModel_KNN', 'StackerEnsembleModel_CatBoost', 'StackerEnsembleModel_XGBoost'}
# Bagging used: True  (with 10 folds)
# Multi-layer stack-ensembling used: True  (with 3 levels)
# Feature Metadata (Processed):
# (raw dtype, special dtypes):
# ('float', [])     : 13 | ['Admission grade', 'Curricular units 1st sem (grade)', 'Curricular units 2nd sem (grade)', 'GDP', 'Inflation rate', ...]
# ('int', [])       : 21 | ['Age at enrollment', 'Application mode', 'Application order', 'Course', 'Curricular units 1st sem (approved)', ...]
# ('int', ['bool']) :  8 | ['Daytime/evening attendance', 'Debtor', 'Displaced', 'Educational special needs', 'Gender', ...]
# D:\programesx64\Anaconda3\envs\mykaggle\lib\site-packages\autogluon\core\utils\plots.py:169: UserWarning: AutoGluon summary plots cannot be created because bokeh is not installed. To see plots, please do: "pip install bokeh==2.0.1"
#   warnings.warn('AutoGluon summary plots cannot be created because bokeh is not installed. To see plots, please do: "pip install bokeh==2.0.1"')
# *** End of fit() summary ***
# {'model_types': {'KNeighborsDist_BAG_L1': 'StackerEnsembleModel_KNN', 'RandomForestGini_BAG_L1': 'StackerEnsembleModel_RF', 'RandomForestEntr_BAG_L1': 'StackerEnsembleModel_RF', 'CatBoost_BAG_L1\\T1': 'StackerEnsembleModel_CatBoost', 'XGBoost_BAG_L1\\T2': 'StackerEnsembleModel_XGBoost', 'LightGBMLarge_BAG_L1': 'StackerEnsembleModel_LGB', 'CatBoost_r177_BAG_L1': 'StackerEnsembleModel_CatBoost', 'LightGBM_r131_BAG_L1': 'StackerEnsembleModel_LGB', 'CatBoost_r9_BAG_L1': 'StackerEnsembleModel_CatBoost', 'LightGBM_r96_BAG_L1': 'StackerEnsembleModel_LGB', 'CatBoost_r137_BAG_L1': 'StackerEnsembleModel_CatBoost', 'CatBoost_r13_BAG_L1': 'StackerEnsembleModel_CatBoost', 'CatBoost_r50_BAG_L1': 'StackerEnsembleModel_CatBoost', 'CatBoost_r69_BAG_L1': 'StackerEnsembleModel_CatBoost', 'LightGBM_r161_BAG_L1': 'StackerEnsembleModel_LGB', 'NeuralNetFastAI_r143_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular', 'CatBoost_r70_BAG_L1': 'StackerEnsembleModel_CatBoost', 'NeuralNetFastAI_r156_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular', 'LightGBM_r196_BAG_L1': 'StackerEnsembleModel_LGB', 'RandomForest_r39_BAG_L1': 'StackerEnsembleModel_RF', 'CatBoost_r167_BAG_L1': 'StackerEnsembleModel_CatBoost', 'XGBoost_r98_BAG_L1': 'StackerEnsembleModel_XGBoost', 'LightGBM_r15_BAG_L1': 'StackerEnsembleModel_LGB', 'CatBoost_r86_BAG_L1': 'StackerEnsembleModel_CatBoost', 'CatBoost_r49_BAG_L1': 'StackerEnsembleModel_CatBoost', 'ExtraTrees_r49_BAG_L1': 'StackerEnsembleModel_XT', 'LightGBM_r143_BAG_L1': 'StackerEnsembleModel_LGB', 'RandomForest_r127_BAG_L1': 'StackerEnsembleModel_RF', 'NeuralNetFastAI_r134_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular', 'RandomForest_r34_BAG_L1': 'StackerEnsembleModel_RF', 'LightGBM_r94_BAG_L1': 'StackerEnsembleModel_LGB', 'CatBoost_r128_BAG_L1': 'StackerEnsembleModel_CatBoost', 'NeuralNetFastAI_r111_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular', 'ExtraTrees_r4_BAG_L1': 'StackerEnsembleModel_XT', 'NeuralNetFastAI_r65_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular', 'NeuralNetFastAI_r88_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular', 'CatBoost_r5_BAG_L1': 'StackerEnsembleModel_CatBoost', 'CatBoost_r6_BAG_L1': 'StackerEnsembleModel_CatBoost', 'CatBoost_r180_BAG_L1': 'StackerEnsembleModel_CatBoost', 'CatBoost_r12_BAG_L1': 'StackerEnsembleModel_CatBoost', 'ExtraTrees_r126_BAG_L1': 'StackerEnsembleModel_XT', 'NeuralNetFastAI_r100_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular', 'CatBoost_r163_BAG_L1': 'StackerEnsembleModel_CatBoost', 'CatBoost_r198_BAG_L1': 'StackerEnsembleModel_CatBoost', 'NeuralNetFastAI_r187_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular', 'XGBoost_r95_BAG_L1': 'StackerEnsembleModel_XGBoost', 'XGBoost_r34_BAG_L1': 'StackerEnsembleModel_XGBoost', 'WeightedEnsemble_L2': 'WeightedEnsembleModel', 'WeightedEnsemble_L3': 'WeightedEnsembleModel'}, 'model_performance': {'KNeighborsDist_BAG_L1': -1.6907816889867084, 'RandomForestGini_BAG_L1': -0.520387765034096, 'RandomForestEntr_BAG_L1': -0.5191453922438883, 'CatBoost_BAG_L1\\T1': -0.5911279980987149, 'XGBoost_BAG_L1\\T2': -0.5302233346243651, 'LightGBMLarge_BAG_L1': -0.7109985189599748, 'CatBoost_r177_BAG_L1': -0.4629089555680481, 'LightGBM_r131_BAG_L1': -0.5860268960883281, 'CatBoost_r9_BAG_L1': -0.6537583050329768, 'LightGBM_r96_BAG_L1': -0.5619501258349061, 'CatBoost_r137_BAG_L1': -0.7169452051345766, 'CatBoost_r13_BAG_L1': -1.0044706908868406, 'CatBoost_r50_BAG_L1': -0.6344962149387989, 'CatBoost_r69_BAG_L1': -0.6737667385540984, 'LightGBM_r161_BAG_L1': -0.8060707098361951, 'NeuralNetFastAI_r143_BAG_L1': -0.49579676357801206, 'CatBoost_r70_BAG_L1': -0.5684550121560096, 'NeuralNetFastAI_r156_BAG_L1': -0.5182403488068342, 'LightGBM_r196_BAG_L1': -0.9257460200060856, 'RandomForest_r39_BAG_L1': -0.5902699555726022, 'CatBoost_r167_BAG_L1': -0.4628615111377822, 'XGBoost_r98_BAG_L1': -0.8619612430927703, 'LightGBM_r15_BAG_L1': -0.5199682691761893, 'CatBoost_r86_BAG_L1': -0.6489185042402897, 'CatBoost_r49_BAG_L1': -0.4662487460571805, 'ExtraTrees_r49_BAG_L1': -0.490311170822412 ...
# 0           WeightedEnsemble_L3  -0.446944    log_loss       4.045482
# 1           WeightedEnsemble_L2  -0.446944    log_loss       4.047482
# 2            XGBoost_r95_BAG_L1  -0.449831    log_loss       0.406260
# 3          CatBoost_r163_BAG_L1  -0.450737    log_loss       0.045991
# 4          ExtraTrees_r4_BAG_L1  -0.458633    log_loss       1.390878
# 5       RandomForest_r34_BAG_L1  -0.460673    log_loss       0.947878
# 6          CatBoost_r167_BAG_L1  -0.462862    log_loss       0.045991
# 7          CatBoost_r177_BAG_L1  -0.462909    log_loss       0.052000
# 8           CatBoost_r49_BAG_L1  -0.466249    log_loss       0.055991
# 9          CatBoost_r198_BAG_L1  -0.466944    log_loss       0.044992
# 10       ExtraTrees_r126_BAG_L1  -0.467616    log_loss       3.298999
# 11  NeuralNetFastAI_r187_BAG_L1  -0.471066    log_loss       0.438286
# 12          LightGBM_r94_BAG_L1  -0.482733    log_loss       0.439003
# 13   NeuralNetFastAI_r88_BAG_L1  -0.485912    log_loss       0.557202
# 14        ExtraTrees_r49_BAG_L1  -0.490311    log_loss       3.433643
# 15  NeuralNetFastAI_r143_BAG_L1  -0.495797    log_loss       0.592002
# 16  NeuralNetFastAI_r134_BAG_L1  -0.497961    log_loss       0.635551
# 17  NeuralNetFastAI_r111_BAG_L1  -0.499124    log_loss       0.484010
# 18          CatBoost_r12_BAG_L1  -0.507718    log_loss       0.047009
# 19  NeuralNetFastAI_r156_BAG_L1  -0.518240    log_loss       0.416003
# 20      RandomForestEntr_BAG_L1  -0.519145    log_loss       1.758325
# 21          LightGBM_r15_BAG_L1  -0.519968    log_loss       0.344008
# 22      RandomForestGini_BAG_L1  -0.520388    log_loss       1.892724
# 23     RandomForest_r127_BAG_L1  -0.525006    log_loss       0.570998
# 24            XGBoost_BAG_L1\T2  -0.530223    log_loss       0.227010
# 25          LightGBM_r96_BAG_L1  -0.561950    log_loss       0.483004
# 26          CatBoost_r70_BAG_L1  -0.568455    log_loss       0.062000
# 27         LightGBM_r131_BAG_L1  -0.586027    log_loss       0.340485
# 28           CatBoost_r6_BAG_L1  -0.589162    log_loss       0.629084
# 29      RandomForest_r39_BAG_L1  -0.590270    log_loss       0.694706
# 30           CatBoost_BAG_L1\T1  -0.591128    log_loss       0.080002
# 31           XGBoost_r34_BAG_L1  -0.616383    log_loss       0.419000
# 32           CatBoost_r5_BAG_L1  -0.631557    log_loss       0.647580
# 33          CatBoost_r50_BAG_L1  -0.634496    log_loss       0.498986
# 34         CatBoost_r128_BAG_L1  -0.646067    log_loss       0.049997
# 35          CatBoost_r86_BAG_L1  -0.648919    log_loss       0.049000
# 36           CatBoost_r9_BAG_L1  -0.653758    log_loss       0.061988
# 37          CatBoost_r69_BAG_L1  -0.673767    log_loss       0.675998
# 38  NeuralNetFastAI_r100_BAG_L1  -0.679108    log_loss       0.547997
# 39         LightGBMLarge_BAG_L1  -0.710999    log_loss       0.132987
# 40         CatBoost_r137_BAG_L1  -0.716945    log_loss       0.791060
# 41         LightGBM_r143_BAG_L1  -0.752009    log_loss       0.179627
# 42   NeuralNetFastAI_r65_BAG_L1  -0.775071    log_loss       0.498995
# 43         CatBoost_r180_BAG_L1  -0.784844    log_loss       0.453005
# 44         LightGBM_r161_BAG_L1  -0.806071    log_loss       0.220997
# 45           XGBoost_r98_BAG_L1  -0.861961    log_loss       0.182000
# 46         LightGBM_r196_BAG_L1  -0.925746    log_loss       0.209002
# 47          CatBoost_r13_BAG_L1  -1.004471    log_loss       0.499630
# 48        KNeighborsDist_BAG_L1  -1.690782    log_loss       6.627963
#
#      fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  \
# 0   80.381608                0.012000           7.781796            3
# 1   80.499042                0.013999           7.899230            2
# 2   14.153855                0.406260          14.153855            1
# 3   13.938991                0.045991          13.938991            1
# 4   10.911598                1.390878          10.911598            1
# 5   10.643556                0.947878          10.643556            1
# 6   14.067638                0.045991          14.067638            1
# 7   13.957280                0.052000          13.957280            1
# 8   13.990483                0.055991          13.990483            1
# 9   15.128544                0.044992          15.128544            1
# 10   9.676782                3.298999           9.676782            1
# 11  13.755343                0.438286          13.755343            1
# 12  14.607882                0.439003          14.607882            1
# 13  14.200957                0.557202          14.200957            1
# 14  11.033385                3.433643          11.033385            1
# 15  14.014552                0.592002          14.014552            1
# 16  13.576956                0.635551          13.576956            1
# 17  13.422366                0.484010          13.422366            1
# 18  13.921575                0.047009          13.921575            1
# 19  13.907968                0.416003          13.907968            1
# 20   8.603080                1.758325           8.603080            1
# 21  14.454400                0.344008          14.454400            1
# 22   9.537316                1.892724           9.537316            1
# 23  10.880188                0.570998          10.880188            1
# 24  11.227513                0.227010          11.227513            1
# 25  14.503854                0.483004          14.503854            1
# 26  13.933136                0.062000          13.933136            1
# 27  14.591870                0.340485          14.591870            1
# 28  14.071275                0.629084          14.071275            1
# 29  10.822741                0.694706          10.822741            1
# 30  12.805397                0.080002          12.805397            1
# 31  14.252050                0.419000          14.252050            1
# 32  14.572292                0.647580          14.572292            1
# 33  14.270607                0.498986          14.270607            1
# 34  13.849498                0.049997          13.849498            1
# 35  13.822857                0.049000          13.822857            1
# 36  13.943293                0.061988          13.943293            1
# 37  14.261036                0.675998          14.261036            1
# 38  12.847395                0.547997          12.847395            1
# 39  13.356308                0.132987          13.356308            1
# 40  14.777922                0.791060          14.777922            1
# 41  14.563717                0.179627          14.563717            1
# 42  13.933954                0.498995          13.933954            1
# 43  13.497142                0.453005          13.497142            1
# 44  14.801035                0.220997          14.801035            1
# 45  14.268306                0.182000          14.268306            1
# 46  14.366760                0.209002          14.366760            1
# 47  13.845011                0.499630          13.845011            1
# 48   6.834961                6.627963           6.834961            1
#
#     can_infer  fit_order
# 0        True         49
# 1        True         48
# 2        True         46
# 3        True         43
# 4        True         34
# 5        True         30
# 6        True         21
# 7        True          7
# 8        True         25
# 9        True         44
# 10       True         41
# 11       True         45
# 12       True         31
# 13       True         36
# 14       True         26
# 15       True         16
# 16       True         29
# 17       True         33
# 18       True         40
# 19       True         18
# 20       True          3
# 21       True         23
# 22       True          2
# 23       True         28
# 24       True          5
# 25       True         10
# 26       True         17
# 27       True          8
# 28       True         38
# 29       True         20
# 30       True          4
# 31       True         47
# 32       True         37
# 33       True         13
# 34       True         32
# 35       True         24
# 36       True          9
# 37       True         14
# 38       True         42
# 39       True          6
# 40       True         11
# 41       True         27
# 42       True         35
# 43       True         39
# 44       True         15
# 45       True         22
# 46       True         19
# 47       True         12
# 48       True          1  }
# ++++++++++++++++++++++++++++++++++++++++++++++
# These features in provided data are not utilized by the predictor and will be ignored: ['academic_0624_v1']
#                           model  score_test  score_val eval_metric  \
# 0         KNeighborsDist_BAG_L1   -0.000039  -1.690782    log_loss
# 1       RandomForestEntr_BAG_L1   -0.110315  -0.519145    log_loss
# 2       RandomForestGini_BAG_L1   -0.111313  -0.520388    log_loss
# 3         ExtraTrees_r49_BAG_L1   -0.113509  -0.490311    log_loss
# 4       RandomForest_r39_BAG_L1   -0.160980  -0.590270    log_loss
# 5      RandomForest_r127_BAG_L1   -0.252110  -0.525006    log_loss
# 6        ExtraTrees_r126_BAG_L1   -0.256666  -0.467616    log_loss
# 7           WeightedEnsemble_L2   -0.309237  -0.446944    log_loss
# 8           WeightedEnsemble_L3   -0.319793  -0.446944    log_loss
# 9          ExtraTrees_r4_BAG_L1   -0.400508  -0.458633    log_loss
# 10      RandomForest_r34_BAG_L1   -0.410376  -0.460673    log_loss
# 11           XGBoost_r95_BAG_L1   -0.428276  -0.449831    log_loss
# 12         CatBoost_r163_BAG_L1   -0.441499  -0.450737    log_loss
# 13         CatBoost_r167_BAG_L1   -0.454550  -0.462862    log_loss
# 14         CatBoost_r177_BAG_L1   -0.456900  -0.462909    log_loss
# 15   NeuralNetFastAI_r88_BAG_L1   -0.458728  -0.485912    log_loss
# 16         CatBoost_r198_BAG_L1   -0.461933  -0.466944    log_loss
# 17  NeuralNetFastAI_r187_BAG_L1   -0.461991  -0.471066    log_loss
# 18          CatBoost_r49_BAG_L1   -0.463064  -0.466249    log_loss
# 19          LightGBM_r94_BAG_L1   -0.477614  -0.482733    log_loss
# 20  NeuralNetFastAI_r143_BAG_L1   -0.482087  -0.495797    log_loss
# 21  NeuralNetFastAI_r134_BAG_L1   -0.484331  -0.497961    log_loss
# 22  NeuralNetFastAI_r111_BAG_L1   -0.484478  -0.499124    log_loss
# 23  NeuralNetFastAI_r156_BAG_L1   -0.500495  -0.518240    log_loss
# 24          CatBoost_r12_BAG_L1   -0.503650  -0.507718    log_loss
# 25          LightGBM_r15_BAG_L1   -0.514618  -0.519968    log_loss
# 26            XGBoost_BAG_L1\T2   -0.518344  -0.530223    log_loss
# 27          LightGBM_r96_BAG_L1   -0.559226  -0.561950    log_loss
# 28          CatBoost_r70_BAG_L1   -0.564237  -0.568455    log_loss
# 29           XGBoost_r34_BAG_L1   -0.572194  -0.616383    log_loss
# 30         LightGBM_r131_BAG_L1   -0.576012  -0.586027    log_loss
# 31           CatBoost_r6_BAG_L1   -0.586967  -0.589162    log_loss
# 32           CatBoost_BAG_L1\T1   -0.588439  -0.591128    log_loss
# 33          CatBoost_r50_BAG_L1   -0.630374  -0.634496    log_loss
# 34           CatBoost_r5_BAG_L1   -0.630385  -0.631557    log_loss
# 35         CatBoost_r128_BAG_L1   -0.640297  -0.646067    log_loss
# 36          CatBoost_r86_BAG_L1   -0.643989  -0.648919    log_loss
# 37  NeuralNetFastAI_r100_BAG_L1   -0.644490  -0.679108    log_loss
# 38           CatBoost_r9_BAG_L1   -0.649777  -0.653758    log_loss
# 39          CatBoost_r69_BAG_L1   -0.671774  -0.673767    log_loss
# 40         LightGBMLarge_BAG_L1   -0.695933  -0.710999    log_loss
# 41         CatBoost_r137_BAG_L1   -0.714602  -0.716945    log_loss
# 42         LightGBM_r143_BAG_L1   -0.737144  -0.752009    log_loss
# 43   NeuralNetFastAI_r65_BAG_L1   -0.753936  -0.775071    log_loss
# 44         CatBoost_r180_BAG_L1   -0.762876  -0.784844    log_loss
# 45         LightGBM_r161_BAG_L1   -0.789378  -0.806071    log_loss
# 46           XGBoost_r98_BAG_L1   -0.851664  -0.861961    log_loss
# 47         LightGBM_r196_BAG_L1   -0.923994  -0.925746    log_loss
# 48          CatBoost_r13_BAG_L1   -1.004122  -1.004471    log_loss
#
#     pred_time_test  pred_time_val   fit_time  pred_time_test_marginal  \
# 0         5.144002       6.627963   6.834961                 5.144002
# 1         0.588000       1.758325   8.603080                 0.588000
# 2         0.682731       1.892724   9.537316                 0.682731
# 3         1.532146       3.433643  11.033385                 1.532146
# 4         0.212003       0.694706  10.822741                 0.212003
# 5         0.142999       0.570998  10.880188                 0.142999
# 6         1.283432       3.298999   9.676782                 1.283432
# 7         4.649569       4.047482  80.499042                 0.019001
# 8         4.643568       4.045482  80.381608                 0.013000
# 9         0.272144       1.390878  10.911598                 0.272144
# 10        0.171999       0.947878  10.643556                 0.171999
# 11        1.620972       0.406260  14.153855                 1.620972
# 12        0.164001       0.045991  13.938991                 0.164001
# 13        0.097000       0.045991  14.067638                 0.097000
# 14        0.125006       0.052000  13.957280                 0.125006
# 15        1.902593       0.557202  14.200957                 1.902593
# 16        0.126003       0.044992  15.128544                 0.126003
# 17        1.875937       0.438286  13.755343                 1.875937
# 18        0.122576       0.055991  13.990483                 0.122576
# 19        1.815326       0.439003  14.607882                 1.815326
# 20        2.010291       0.592002  14.014552                 2.010291
# 21        2.514393       0.635551  13.576956                 2.514393
# 22        1.768796       0.484010  13.422366                 1.768796
# 23        1.391758       0.416003  13.907968                 1.391758
# 24        0.085003       0.047009  13.921575                 0.085003
# 25        1.235794       0.344008  14.454400                 1.235794
# 26        1.770069       0.227010  11.227513                 1.770069
# 27        1.929606       0.483004  14.503854                 1.929606
# 28        0.161190       0.062000  13.933136                 0.161190
# 29        1.811750       0.419000  14.252050                 1.811750
# 30        1.747576       0.340485  14.591870                 1.747576
# 31        0.094001       0.629084  14.071275                 0.094001
# 32        0.114002       0.080002  12.805397                 0.114002
# 33        0.080003       0.498986  14.270607                 0.080003
# 34        0.070516       0.647580  14.572292                 0.070516
# 35        0.144001       0.049997  13.849498                 0.144001
# 36        0.087290       0.049000  13.822857                 0.087290
# 37        2.475467       0.547997  12.847395                 2.475467
# 38        0.151001       0.061988  13.943293                 0.151001
# 39        0.061997       0.675998  14.261036                 0.061997
# 40        1.040782       0.132987  13.356308                 1.040782
# 41        0.061000       0.791060  14.777922                 0.061000
# 42        0.728629       0.179627  14.563717                 0.728629
# 43        1.762674       0.498995  13.933954                 1.762674
# 44        0.090997       0.453005  13.497142                 0.090997
# 45        0.910676       0.220997  14.801035                 0.910676
# 46        0.700650       0.182000  14.268306                 0.700650
# 47        0.886656       0.209002  14.366760                 0.886656
# 48        0.051000       0.499630  13.845011                 0.051000
#
#     pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
# 0                 6.627963           6.834961            1       True
# 1                 1.758325           8.603080            1       True
# 2                 1.892724           9.537316            1       True
# 3                 3.433643          11.033385            1       True
# 4                 0.694706          10.822741            1       True
# 5                 0.570998          10.880188            1       True
# 6                 3.298999           9.676782            1       True
# 7                 0.013999           7.899230            2       True
# 8                 0.012000           7.781796            3       True
# 9                 1.390878          10.911598            1       True
# 10                0.947878          10.643556            1       True
# 11                0.406260          14.153855            1       True
# 12                0.045991          13.938991            1       True
# 13                0.045991          14.067638            1       True
# 14                0.052000          13.957280            1       True
# 15                0.557202          14.200957            1       True
# 16                0.044992          15.128544            1       True
# 17                0.438286          13.755343            1       True
# 18                0.055991          13.990483            1       True
# 19                0.439003          14.607882            1       True
# 20                0.592002          14.014552            1       True
# 21                0.635551          13.576956            1       True
# 22                0.484010          13.422366            1       True
# 23                0.416003          13.907968            1       True
# 24                0.047009          13.921575            1       True
# 25                0.344008          14.454400            1       True
# 26                0.227010          11.227513            1       True
# 27                0.483004          14.503854            1       True
# 28                0.062000          13.933136            1       True
# 29                0.419000          14.252050            1       True
# 30                0.340485          14.591870            1       True
# 31                0.629084          14.071275            1       True
# 32                0.080002          12.805397            1       True
# 33                0.498986          14.270607            1       True
# 34                0.647580          14.572292            1       True
# 35                0.049997          13.849498            1       True
# 36                0.049000          13.822857            1       True
# 37                0.547997          12.847395            1       True
# 38                0.061988          13.943293            1       True
# 39                0.675998          14.261036            1       True
# 40                0.132987          13.356308            1       True
# 41                0.791060          14.777922            1       True
# 42                0.179627          14.563717            1       True
# 43                0.498995          13.933954            1       True
# 44                0.453005          13.497142            1       True
# 45                0.220997          14.801035            1       True
# 46                0.182000          14.268306            1       True
# 47                0.209002          14.366760            1       True
# 48                0.499630          13.845011            1       True
#
#     fit_order
# 0           1
# 1           3
# 2           2
# 3          26
# 4          20
# 5          28
# 6          41
# 7          48
# 8          49
# 9          34
# 10         30
# 11         46
# 12         43
# 13         21
# 14          7
# 15         36
# 16         44
# 17         45
# 18         25
# 19         31
# 20         16
# 21         29
# 22         33
# 23         18
# 24         40
# 25         23
# 26          5
# 27         10
# 28         17
# 29         47
# 30          8
# 31         38
# 32          4
# 33         13
# 34         37
# 35         32
# 36         24
# 37         42
# 38          9
# 39         14
# 40          6
# 41         11
# 42         27
# 43         35
# 44         39
# 45         15
# 46         22
# 47         19
# 48         12
# ++++++++++++++++++++++++++++++++++++++++++++++
#                                                 importance    stddev  \
# Curricular units 2nd sem (approved)               0.491628  0.007062
# Curricular units 1st sem (approved)               0.096452  0.002925
# Curricular units 2nd sem (grade)                  0.083493  0.001796
# Tuition fees up to date                           0.079391  0.004098
# Curricular units 1st sem (grade)                  0.051124  0.001022
# Curricular units 2nd sem (evaluations)            0.048631  0.001759
# Curricular units 1st sem (evaluations)            0.042805  0.001203
# Scholarship holder                                0.042671  0.001840
# std_features                                      0.035178  0.000699
# Age at enrollment                                 0.027764  0.000709
# sum_features                                      0.026379  0.000569
# mean_features                                     0.025939  0.000482
# Admission grade                                   0.024446  0.000641
# Curricular units 2nd sem (enrolled)               0.022203  0.000401
# Previous qualification (grade)                    0.019665  0.000979
# median_features                                   0.019024  0.000471
# Curricular units 1st sem (enrolled)               0.015859  0.000515
# Application mode                                  0.014092  0.000487
# Father's occupation                               0.013593  0.000433
# Unemployment rate                                 0.013023  0.000517
# Mother's occupation                               0.012827  0.000228
# Gender                                            0.012245  0.000669
# GDP                                               0.011356  0.000661
# Mother's qualification                            0.010379  0.000389
# max_features                                      0.009562  0.000125
# Inflation rate                                    0.009523  0.000328
# Father's qualification                            0.009408  0.000366
# Course                                            0.009394  0.000201
# Application order                                 0.006972  0.000255
# Debtor                                            0.006522  0.000942
# min_features                                      0.005331  0.000351
# Displaced                                         0.004566  0.000186
# Previous qualification                            0.001961  0.000074
# Curricular units 1st sem (credited)               0.001393  0.000247
# Curricular units 2nd sem (credited)               0.001121  0.000294
# Marital status                                    0.000910  0.000058
# Curricular units 1st sem (without evaluations)    0.000839  0.000250
# Daytime/evening attendance                        0.000663  0.000040
# Curricular units 2nd sem (without evaluations)    0.000659  0.000155
# Nacionality                                       0.000136  0.000099
# Educational special needs                         0.000066  0.000039
# International                                     0.000063  0.000032
#
#                                                      p_value  n  p99_high  \
# Curricular units 2nd sem (approved)             5.106281e-09  5  0.506167
# Curricular units 1st sem (approved)             1.013502e-07  5  0.102474
# Curricular units 2nd sem (grade)                2.569760e-08  5  0.087192
# Tuition fees up to date                         8.484870e-07  5  0.087828
# Curricular units 1st sem (grade)                1.912442e-08  5  0.053227
# Curricular units 2nd sem (evaluations)          2.049825e-07  5  0.052253
# Curricular units 1st sem (evaluations)          7.485106e-08  5  0.045282
# Scholarship holder                              4.137661e-07  5  0.046459
# std_features                                    1.872777e-08  5  0.036618
# Age at enrollment                               5.104372e-08  5  0.029224
# sum_features                                    2.604361e-08  5  0.027551
# mean_features                                   1.431401e-08  5  0.026932
# Admission grade                                 5.680606e-08  5  0.025767
# Curricular units 2nd sem (enrolled)             1.270373e-08  5  0.023028
# Previous qualification (grade)                  7.341220e-07  5  0.021680
# median_features                                 4.504980e-08  5  0.019994
# Curricular units 1st sem (enrolled)             1.333992e-07  5  0.016919
# Application mode                                1.712738e-07  5  0.015095
# Father's occupation                             1.228225e-07  5  0.014484
# Unemployment rate                               2.963527e-07  5  0.014086
# Mother's occupation                             1.202900e-08  5  0.013297
# Gender                                          1.062703e-06  5  0.013622
# GDP                                             1.368965e-06  5  0.012716
# Mother's qualification                          2.356193e-07  5  0.011179
# max_features                                    3.531979e-09  5  0.009820
# Inflation rate                                  1.691987e-07  5  0.010199
# Father's qualification                          2.754256e-07  5  0.010162
# Course                                          2.507830e-08  5  0.009807
# Application order                               2.152118e-07  5  0.007498
# Debtor                                          5.072660e-05  5  0.008461
# min_features                                    2.234160e-06  5  0.006053
# Displaced                                       3.288261e-07  5  0.004948
# Previous qualification                          2.483105e-07  5  0.002114
# Curricular units 1st sem (credited)             1.144741e-04  5  0.001903
# Curricular units 2nd sem (credited)             5.173173e-04  5  0.001726
# Marital status                                  2.009170e-06  5  0.001030
# Curricular units 1st sem (without evaluations)  8.481973e-04  5  0.001354
# Daytime/evening attendance                      1.534431e-06  5  0.000744
# Curricular units 2nd sem (without evaluations)  3.388821e-04  5  0.000978
# Nacionality                                     1.873483e-02  5  0.000340
# Educational special needs                       9.660492e-03  5  0.000146
# International                                   5.815257e-03  5  0.000128
#
#                                                  p99_low
# Curricular units 2nd sem (approved)             0.477088
# Curricular units 1st sem (approved)             0.090429
# Curricular units 2nd sem (grade)                0.079794
# Tuition fees up to date                         0.070954
# Curricular units 1st sem (grade)                0.049020
# Curricular units 2nd sem (evaluations)          0.045010
# Curricular units 1st sem (evaluations)          0.040327
# Scholarship holder                              0.038882
# std_features                                    0.033738
# Age at enrollment                               0.026304
# sum_features                                    0.025206
# mean_features                                   0.024947
# Admission grade                                 0.023126
# Curricular units 2nd sem (enrolled)             0.021378
# Previous qualification (grade)                  0.017650
# median_features                                 0.018054
# Curricular units 1st sem (enrolled)             0.014798
# Application mode                                0.013088
# Father's occupation                             0.012703
# Unemployment rate                               0.011959
# Mother's occupation                             0.012357
# Gender                                          0.010868
# GDP                                             0.009996
# Mother's qualification                          0.009579
# max_features                                    0.009304
# Inflation rate                                  0.008847
# Father's qualification                          0.008654
# Course                                          0.008980
# Application order                               0.006447
# Debtor                                          0.004583
# min_features                                    0.004609
# Displaced                                       0.004183
# Previous qualification                          0.001808
# Curricular units 1st sem (credited)             0.000884
# Curricular units 2nd sem (credited)             0.000516
# Marital status                                  0.000790
# Curricular units 1st sem (without evaluations)  0.000323
# Daytime/evening attendance                      0.000581
# Curricular units 2nd sem (without evaluations)  0.000341
# Nacionality                                    -0.000068
# Educational special needs                      -0.000014
# International                                  -0.000003
# ++++++++++++++++++++++++++++++++++++++++++++++
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 pipline(df_cp.sample(frac=0.7),df_test_cp,label='Target',loss='log_loss',time=60*60*6,id_name='academic_0624_v1',cols=['id','Target'])
#
# Cell In[2], line 107, in pipline(df1, df1_test, label, time, id_name, loss, cols)
#     105 show_info(predictor,train_x)
#     106 # titanic_acc(predictions)
# --> 107 submission(predictions,test_x,cols,label,id_name)
#     108 return predictions
#
# Cell In[2], line 95, in submission(predictions, test_x, cols, label, id_name)
#      93 def submission(predictions,test_x,cols,label,id_name):
#      94     test_x[label] = predictions
# ---> 95     test_x[cols].to_csv(f'submission_{id_name}.csv',index=False)
#
# File D:\programesx64\Anaconda3\envs\mykaggle\lib\site-packages\pandas\core\frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File D:\programesx64\Anaconda3\envs\mykaggle\lib\site-packages\pandas\core\indexes\base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# File D:\programesx64\Anaconda3\envs\mykaggle\lib\site-packages\pandas\core\indexes\base.py:6252, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6249     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6251 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6252 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['id'] not in index"

# %%
# import 
tmp = pd.read_csv('./model_hc_ts_academic_0624_v1.csv')
test = pd.read_csv('df_test.csv')
test['Target'] = tmp['academic_0624_v1']
test[['id','Target']].to_csv('submission_academic_0624_v1.csv',index=False)

# %%
def submission(predictions,test_x,cols,label,id_name):
    test_x[label] = predictions
    test_x[cols].to_csv(f'submission_{id_name}.csv',index=False)
# test = pandas.read_csv('df_test.csv')
submission(pd,test,['id','Target'],'Target','academic_0624_v1_flaml')

# %%
# !kaggle competitions submit -c playground-series-s4e6 -f submission_academic_0624_v1.csv -m "Message"
# Out:
# Successfully submitted to Classification with an Academic Success Dataset
#   0%|          | 0.00/809k [00:00<?, ?B/s]
#   1%|          | 8.00k/809k [00:00<00:42, 19.4kB/s]
# 100%|██████████| 809k/809k [00:03<00:00, 252kB/s]
